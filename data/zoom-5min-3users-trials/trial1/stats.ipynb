# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("stats.csv")

# Compute loss rate: lost / (pkts + lost)
df["loss_rate"] = df["lost"] / (df["pkts"] + df["lost"])

# Group by timestamp and compute average loss rate
loss_rate_per_time = df.groupby("ts_s")["loss_rate"].mean().reset_index()

print(loss_rate_per_time.head())


loss_rate_per_time.to_csv("loss_rate_per_time.csv", index=False)

# Plot (optional)
import matplotlib.pyplot as plt
plt.plot(loss_rate_per_time["ts_s"], loss_rate_per_time["loss_rate"])
plt.xlabel("Timestamp")
plt.ylabel("Loss Rate")
plt.title("Packet Loss Rate Over Time")
plt.show()



# this zoom packet had the zoom running for some time
# Out:
#          ts_s  loss_rate
# 0  1776259615   0.000000
# 1  1776259616   0.012500
# 2  1776259617   0.019481
# 3  1776259618   0.019802
# 4  1776259619   0.006969

# %%
# change the networks 

# switch the network on the laptop with the stress result, for the users. User nnumbers are the same, 


# try wifi on hotspot , can do smae thing on 3 users, set one user on wifi and 2 on hotpsot, whichever easier 

# try to do the same thing with the stress test, but with the stress test running, and see if we can get the same results.

# identify the packet form thuser, you have 


# start with two users in networking environments , set up the experminet 

#
